# %%
lst = eval(input())
lst = list(set(lst))
t = int(input())
def target(t):
    count = 0
    for i in range(len(lst)):
        for j in range(i+1, len(list)):
            if lst[i] + lst[j] == t:
                count += 1
    return count
print(target(t))
